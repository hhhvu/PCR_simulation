# %% [markdown]
# ## Model inspection

# %%
import pandas as pd
import numpy as np

# %%
seq_1_model = pd.read_csv('../data/model_outputs/3_18_Seq_Model_large_val_test_pred_df.csv')
seq_gene_1_model = pd.read_csv('../data/model_outputs/3_18_Seq_Gene_Model_large_val_test_pred_df.csv')
image_1_model = pd.read_csv('../data/model_outputs/3_18_Image_Model_large_val_test_pred_df.csv') 

groundtruth_df = pd.read_csv('../data/new_groundtruth_df_target_data_v1.csv')
print(groundtruth_df.head())
# Out:
#    Unnamed: 0  curve_idx  target              sample_type sample_id  igi_call  \
# 0          44     233557  RnaseP  Negative Control (qPCR)   S370517  Negative
# 1          89     232789  E gene  Negative Control (qPCR)   S370517  Negative
# 2         134     233173  N gene  Negative Control (qPCR)   S370517  Negative
# 3         179     233558  RnaseP  Negative Control (qPCR)   S587856  Negative
# 4         224     232790  E gene  Negative Control (qPCR)   S587856  Negative
#
#    cycle_no          Fn             rn  groundtruth  split  Igi_call_quant  \
# 0        45   24275.140   24275.140625           -1  train               0
# 1        45  276665.900  276665.906250           -1  train               0
# 2        45  111715.734  111715.734375           -1  train               0
# 3        45   19782.184   19782.183594           -1    val               0
# 4        45  256461.700  256461.703125           -1    val               0
#
#    groundtruth_target
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
